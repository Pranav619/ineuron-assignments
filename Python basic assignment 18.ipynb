# %% [raw]
# 1. Create a zoo.py file first. Define the hours() function, which prints the string 'Open 9-5 daily'.
# Then, use the interactive interpreter to import the zoo module and call its hours() function.
# Answer)
# // in zoo.py file//
# def hours():
#     print('Open 9-5 daily')
#
# // now in interpretor //
# from zoo import hours
# hours()
#
# //output comes as : 'Open 9-5 daily'
#
#
#
#
# 2. In the interactive interpreter, import the zoo module as menagerie and call its hours() function.
# import zoo as menagerie
# menagerie.hours()
# //output comes as : 'Open 9-5 daily'
#
#
#
# 3. Using the interpreter, explicitly import and call the hours() function from zoo.
# from zoo import hours
# hours()
#
#
#
# 4. Import the hours() function as info and call it.
# from zoo import hours() as info
# info.hours()
# //output comes as : 'Open 9-5 daily'
#
#
#
#
# 5. Create a plain dictionary with the key-value pairs 'a': 1, 'b': 2, and 'c': 3, and print it out.
#
# ANS)plain={'a': 1 , 'b': 2,'c': 3}
# plain
#
#
# 6.Make an OrderedDict called fancy from the same pairs listed in 5 and print it. Did it print in the
# same order as plain?
#
# ANS) from collections import OrderedDict
# fancy = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
# fancy
#
#
# 7. Make a default dictionary called dict_of_lists and pass it the argument list. Make the list
# dict_of_lists['a'] and append the value 'something for a' to it in one assignment. Print
# dict_of_lists['a'].
#
#
# ANS) from collection import defaultdict
# dict_of_list= defaultdist(list)
# dict_of_list[a]='something for a'
# dict_of_list[a] //printed
