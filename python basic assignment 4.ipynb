# %% [raw]
# 1. What exactly is []?
# Ans )  these are square operator and used for enclosing the index
#
#
# 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the
# third value? (Assume [2, 4, 6, 8, 10] are in spam.)
# ans) spam[2] ='hello'
#
#
# Let's pretend the spam includes the list ['a','b','c','d'] for the next three queries.
#
# 3. What is the value of spam[int(int('3' * 2) / 11)]?
# Ans) the value will be--- 'd'
#
# 4. What is the value of spam[-1]?
# Ans) The value will be -- 'd'
#
# 5. What is the value of spam[:2]?
# ans) the value will be -- ['a', 'b']
#
#
#
# Let's pretend bacon has the list [3.14, 'cat', 11,'cat', True] for the next three questions.
# 6. What is the value of bacon.index('cat')?
# ans) index will be : 1
#
# 7. How does bacon.append(99) change the look of the list value in bacon?
# ans)new list will be:  [3.14, 'cat', 11,'cat', True ,99]
#
# 8. How does bacon.remove('cat') change the look of the list in bacon?
# Ans) new list will be : [3.14, 11,'cat', True,99]
#
#
# 9. What are the list concatenation and list replication operators?
# ans) list concatenation : + , while the operator for replication :  *
#
# 10. What is difference between the list methods append() and insert()?
# ans) append adds in the end of the list while insert can be used to add at any speicific position.
#
# 11. What are the two methods for removing items from a list?
# ans) first one is remove and second one is pop() and clear() can be used to remove all
#
# 12. Describe how list values and string values are identical.
# ans) both have indexes and slices
# both can be passed to len()
# both can be concatenated and replicated
#
#
# 13. What's the difference between tuples and lists?
# Ans) Tuples are static while lists are dynamic.
# also lists are mutable while tuples are not.
#
# 14. How do you type a tuple value that only contains the integer 42?
# ans) we can use the trailing comma
# ex:  s1=('42',)
#
# 15. How do you get a list value's tuple form? How do you get a tuple value's list form?
# ans) we can pass the tuple inside -> list()  to make it a list form
# or we can pass the list inside --> tuple()  to make it a tuple
#
# 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they
# contain?
# ans) they may contain referenceto the list values
#
# 17. How do you distinguish between copy.copy() and copy.deepcopy()? (learnt while doing assignment:)  )
# Ans) A shallow copy constructs a new compound object and then (to the extent possible) inserts references into it to the objects found in the original.
# A deep copy constructs a new compound object and then, recursively, inserts copies into it of the objects found in the original.
