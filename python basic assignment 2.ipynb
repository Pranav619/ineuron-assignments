# %% [raw]
# q1)What are the two values of the Boolean data type? How do you write them?
#
# ans1) boolean has two values that is true(1) and (0)false and we can write it by using bool keyword.
#
#
#
# 2. What are the three different types of Boolean operators?
# Ans2)  the three basic boolean operators are ---  and, or and not
#
#
# 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
# Ans3) 0 and 0 = false(0)
#     0 and 1 = false(0)
#     1 and 0  = false(0)
#     1 and 1 = true(1)
#
#     0 or 0 = false(0)
#     0 or 1 = true(1)
#     1 or 0  = true(1)
#     1 or 1 = true(1)
#
#  not 1 gives 0
#  not 0 gives 1

# %% [raw]
# 4. What are the values of the following expressions?
# (5 > 4) and (3 == 5)
# not (5 > 4)
# (5 > 4) or (3 == 5)
# not ((5 > 4) or (3 == 5))
# (True and True) and (True == False)
# (not False) or (not True)
# Ans4)  false
#        false
#        true
#        false
#        false
#        true
#
#
# 5. What are the six comparison operators?
# ans5) six comparison operators are :
# >  , < , = , <= , >= , !=
#
#
# 6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
# Ans 6) for assigning a value we use  assignment operator which is a single equal to sign i.e. a=10
#
# and as for comparison equal to which is used for comparison b/w two values we use double equal to operator for example
# 5==10 and it will compare these two values. if this operator return 0 it is false statement and if it returns 1 then it is a true statement.
#
#
#
# 7. Identify the three blocks in this code:
# *****first block****
# spam = 0
# if spam == 10:
# print('eggs')
# ***********************
#
# if spam > 5:
# print('bacon')
# else:
# print('ham')
# ****second block ends ********
#
# print('spam')
# print('spam')
#
# ****third block ends ****
#
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
# Ans8)
#
# spam = input("enter a integer:")
#
# if spam == '1':
#     print("hello")
# elif spam == '2':
#     print("Howdy")
# else:
#     print("Greetings!")
#
#
# 9.If your programme is stuck in an endless loop, what keys you’ll press?
# Ans9) we can use ctrl + c command to end

# %% [raw]
# 10. How can you tell the difference between break and continue?
# Ans) Break statement ends the loop and move the cursor outside the loop whereas continue will skip the current teration of
# the loop and move formward
# we can also see that all the statement after break present in the loop are skipped whereas in continue after that specific iteration statements will be considered if the condition turns out to be true
#
#
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
# ans11) here all will print the same
# as range(10) = 0 to 9
# ,and similar range(0,10) starting with 0 and going till less than 10 that is 0 to 9 and similarly
#  for range(0,10,1) start with 0 go till less than 10 and jump 1
#
#
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.
#
# ans12)   program :
# for i in range(1,11):
#     print(i)
#
#  program 2:
#  i=1
# while(i<11):
#     print(i)
#     i=i+1;
#
#
# 13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?
#
# ans13) after importing spam we can do
# spam.bacon()
# to call the bacon function
