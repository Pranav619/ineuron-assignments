# %% [raw]
# 1. Why are functions advantageous to have in your programs?
# ANS1) because functions allow us to use same code again and again , without actually typing it.
# we can also break our problem into smaller parts or functions and then solve it accordingly.
# we don't need to know the working instead we only need input,output and where it lives thus fn.follows
# abstraction.
#
# 2. When does the code in a function run: when its specified or when its called?
# ANS2) The code of the function only runs when it is called , after calling the fn program left the code and
# begin to execute the first of the code.
#
#
# 3. What statement creates a function?
# Ans) Def keyword with function name and parenthisis in the end with colon  ---- creates a fn in a code
# example--  def name():
#
#
# 4. What is the difference between a function and a function call?
# ans) Function is the part where we write the code for it and give the name tand all speific things related to the function
# but after making it
# when we want to use it we call for the name of it and it is where the actual running orimplementation of the
# function took place.
#
#
# 5. How many global scopes are there in a Python program? How many local scopes?
# Ans)There is only one global scope in python program otherwise it would be impractical and for
# local scope there are only one types of it which is when it is declared inside the function.
#
#
#
# 6. What happens to variables in a local scope when the function call returns?
# ans)The local variable can be used outside the function any time after the function call completes and
# local variable retains its value until the next time the function
#
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
# ans) Return value end the recursiveness of a function and a function will end after seeing a return value and
#  If the return statement is without any expression, then the special value None is returned.
#
#
#
#
# 8. If a function does not have a return statement, what is the return value of a call to that function?
# ans) it would return none
#
#
#
# 9. How do you make a function variable refer to the global variable?
# Ans) To create a global variable inside a function, you can use the global keyword.
# or if it is declared outside the fnctions then it is a global variable
#
# 10. What is the data type of None?
# None has a NONEtype of data type itself and is used to define a null value, or no value at all. None is not the same as 0, False, or an empty string.
#
#
# 11. What does the sentence import areallyourpetsnamederic do?
# it will import this module
#
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
# Ans )  spam.bacon()
#
#
# 13. What can you do to save a programme from crashing if it encounters an error?
# Ans ) best we can use is error handling that is use try and except block
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
# ans) try statements are used as If the statement is successful, both except clauses are skipped and the code inside the finally clause is run.
# If the statement inside the try block fails, the code in the first except statement is executed.
