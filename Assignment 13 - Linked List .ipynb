# %% [markdown]
# ## Q1

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

def create_new_linked_list(list1, list2):
    new_head = None
    new_tail = None
    
    while list1 is not None and list2 is not None:
        if list1.data >= list2.data:
            new_node = Node(list1.data)
            list1 = list1.next
        else:
            new_node = Node(list2.data)
            list2 = list2.next
            
        if new_head is None:
            new_head = new_node
            new_tail = new_node
        else:
            new_tail

# %% [markdown]
# ## Q2 Doubt

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

def remove_duplicates(head):
    # If the list is empty or has only one node, return the list
    if head is None or head.next is None:
        return head
    
    current = head
    while current is not None and current.next is not None:
        if current.data == current.next.data:
            # Duplicate found, update the next pointer of the current node to skip the duplicate node
            current.next = current.next.next
        else:
            # Move to the next node
            current = current.next
    
    return head

# Example usage
# Create the linked list
list1 = Node(11)
list1.next = Node(11)
list1.next.next = Node(11)
list1.next.next.next = Node(21)
list1.next.next.next.next = Node(43)
list1.next.next.next.next.next = Node(43)
list1.next.next.next.next.next.next = Node(60)

# %% [markdown]
# ## Q3

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

def reverse_k_nodes(head, k):
    # If the linked list is empty or has only one node, return the list as it is since reversing is not required
    if head is None or head.next is None:
        return head

    current = head
    prev = None
    count = 0

    # Reverse the first k nodes
    while current is not None and count < k:
        next_node = current.next
        current.next = prev
        prev = current
        current = next_node
        count += 1

    # If there are remaining nodes, reverse them recursively
    if current is not None:
        head.next = reverse_k_nodes(current, k)

    return prev

# Function to print the linked list
def print_linked_list(head):
    current = head
    while current is not None:
        print(current.data, end=" ")
        current = current.next
    print()

# Function to create a linked list based on user input
def create_linked_list():
    nums = input("Enter the values for the linked list (space-separated): ").split()
    head = None
    tail = None
    
    for num in nums:
        new_node = Node(int(num))
        
        if head is None:
            head = new_node
            tail = new_node
        else:
            tail.next = new_node
            tail = new_node
    
    return head

# Create the linked list based on user input
list1 = create_linked_list()

# Get the value of k from the user
k = int(input("Enter the value of k: "))

# Reverse every k nodes
new_list = reverse_k_nodes(list1, k)

# Print the modified linked list
print("Modified Linked List:")
print_linked_list(new_list)

# %% [markdown]
# ## Q4

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

def reverse_alternate_k_nodes(head, k):
    if head is None or head.next is None:
        return head

    current = head
    prev = None
    count = 0

    # Reverse alternate k nodes
    while current is not None:
        count += 1

        if count % (2 * k) == k + 1:
            group_prev = prev
            group_current = current
            group_next = None

            for _ in range(k):
                if group_current is None:
                    break

                group_next = group_current.next
                group_current.next = group_prev
                group_prev = group_current
                group_current = group_next

            if prev is None:
                # Update the head of the linked list
                head = group_prev
            else:
                prev.next = group_prev

            current.next = group_current

            prev = current
            current = group_current
        else:
            # Moving to the next node
            prev = current
            current = current.next

    return head

def print_linked_list(head):
    current = head
    while current is not None:
        print(current.data, end="->")
        current = current.next
    print("NULL")

def create_linked_list():
    nums = input("Enter the values for the linked list (space-separated): ").split()
    head = None
    tail = None
    
    for num in nums:
        new_node = Node(int(num))
        
        if head is None:
            head = new_node
            tail = new_node
        else:
            tail.next = new_node
            tail = new_node
    
    return head

list1 = create_linked_list()

k = int(input("Enter the value of k: "))

new_list = reverse_alternate_k_nodes(list1, k)

print("Modified Linked List:")
print_linked_list(new_list)

# %% [markdown]
# ## Q5

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

def delete_last_occurrence(head, key):
    # If the linked list is empty, return None
    if head is None:
        return None

    # Find the last occurrence of the key
    last_occurrence = None
    prev = None
    current = head
    next_node = None

    while current is not None:
        if current.data == key:
            last_occurrence = current
        current = current.next

    # If the last occurrence is found, delete it
    if last_occurrence is not None:
        if last_occurrence == head:
            head = head.next
        else:
            current = head
            while current.next != last_occurrence:
                current = current.next
            current.next = last_occurrence.next

    return head

# Function to print the linked list
def print_linked_list(head):
    current = head
    while current is not None:
        print(current.data, end="->")
        current = current.next
    print("NULL")

# Function to create a linked list based on user input
def create_linked_list():
    nums = input("Enter the values for the linked list (space-separated): ").split()
    head = None
    tail = None
    
    for num in nums:
        new_node = Node(int(num))
        
        if head is None:
            head = new_node
            tail = new_node
        else:
            tail.next = new_node
            tail = new_node
    
    return head

# Create the linked list based on user input
list1 = create_linked_list()

# Get the key to be deleted from the user
key = int(input("Enter the key to be deleted: "))

# Delete the last occurrence of the key
new_list = delete_last_occurrence(list1, key)

# Print the modified linked list
print("Modified Linked List:")
print_linked_list(new_list)

# %% [markdown]
# ## Q6 doubt

# %% [markdown]
# ## Q7

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.prev = None
        self.next = None

def reverse_doubly_linked_list(head):
    current = head
    prev = None

    while current is not None:
        next_node = current.next
        current.next = prev
        current.prev = next_node
        prev = current
        current = next_node

    head = prev
    return head

def print_doubly_linked_list(head):
    current = head
    while current is not None:
        print(current.data, end=" ")
        current = current.next
    print()

def create_doubly_linked_list():
    nums = input("Enter the values for the doubly linked list (space-separated): ").split()
    head = None
    tail = None

    for num in nums:
        new_node = Node(int(num))

        if head is None:
            head = new_node
            tail = new_node
        else:
            tail.next = new_node
            new_node.prev = tail
            tail = new_node

    return head

list1 = create_doubly_linked_list()

print("Original Doubly Linked List:")
print_doubly_linked_list(list1)

reversed_list = reverse_doubly_linked_list(list1)

print("Reversed Doubly Linked List:")
print_doubly_linked_list(reversed_list)

# %% [markdown]
# ## Q8

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.prev = None
        self.next = None

def delete_node_at_position(head, position):
    if head is None:
        return None

    if position == 1:
        head = head.next
        if head is not None:
            head.prev = None
        return head

    current = head
    count = 1

    while current is not None and count < position:
        current = current.next
        count += 1

    if current is None:
        return head

    current.prev.next = current.next
    if current.next is not None:
        current.next.prev = current.prev

    return head

def print_doubly_linked_list(head):
    current = head
    while current is not None:
        print(current.data, end=" ")
        current = current.next
    print()

def create_doubly_linked_list():
    nums = input("Enter the values for the doubly linked list (space-separated): ").split()
    head = None
    tail = None

    for num in nums:
        new_node = Node(int(num))

        if head is None:
            head = new_node
            tail = new_node
        else:
            tail.next = new_node
            new_node.prev = tail
            tail = new_node

    return head

list1 = create_doubly_linked_list()

print("Original Doubly Linked List:")
print_doubly_linked_list(list1)

position = int(input("Enter the position to delete: "))

new_list = delete_node_at_position(list1, position)

print("Modified Doubly Linked List:")
print_doubly_linked_list(new_list)
